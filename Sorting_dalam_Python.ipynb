# %% [markdown]
# <a href="https://colab.research.google.com/github/zardidntsleep/Praktikum-Struktur-Data/blob/main/Sorting_dalam_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Implementasi Bubble Sort

def bubble_sort(arr):
  n = len(arr)
  for i in range(n-1):
    for j in range (n-i-1):
      if arr[j] > arr[j+1]:
        arr[j], arr[j+1] = arr[j+1], arr[j]
  return arr

#Contoh penggunaan
data = [64, 34, 25, 12, 22, 11, 90]
sorted_data = bubble_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Bubble Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 34, 25, 12, 22, 11, 90]
# Data setelah Bubble Sort: [11, 12, 22, 25, 34, 64, 90]

# %%
#Implementasi Selection Sort

def selection_sort(arr):
  n = len(arr)
  for i in range(n-1):
    min_index = i
    for j in range (i+1, n):
      if arr[j] < arr[min_index]:
        min_index = j
    arr[i], arr[min_index] = arr[min_index], arr[i]
  return arr

#Contoh penggunaan
data = [64, 25, 12, 22, 11]
sorted_data = selection_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Selection Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 25, 12, 22, 11]
# Data setelah Selection Sort: [11, 12, 22, 25, 64]

# %%
#Implementasi Insertion Sort

def insertion_sort(arr):
  n = len(arr)
  for i in range(1, n):
    key = arr[i]
    j = i-1
    while j >= 0 and arr[j] > key:
      arr[j+1] = arr[j]
      j -= 1
    arr[j+1] = key
  return arr

#Contoh penggunaan
data = [64, 34, 25, 12, 22, 11, 90]
sorted_data = insertion_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Insertion Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 34, 25, 12, 22, 11, 90]
# Data setelah Bubble Sort: [11, 12, 22, 25, 34, 64, 90]

# %%
#Implementasi Merge Sort

def merge_sort(arr):
  if len(arr) > 1:
    mid = len(arr) // 2
    left_half = arr[:mid]
    right_half = arr[:mid]

    merge_sort(left_half)
    merge_sort(right_half)

    i = j = k = 0

    while i < len(left_half) and j < len(right_half):
      if left_half[i] < right_half[j]:
        arr[k] = left_half[i]
        i += 1
      else:
        arr[k] = right_half[j]
        j += 1
        k += 1
      while i < len(left_half):
        arr[k] = left_half[i]
        i += 1
        k += 1
      while j < len(right_half):
        arr[k] = right_half[j]
        j += 1
        k += 1
    return arr

#Contoh penggunaan
data = [64, 34, 25, 12, 22, 11, 90]
sorted_data = merge_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Merge Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 34, 25, 12, 22, 11, 90]
# Data setelah Bubble Sort: [64, 64, 64, 25, 64, 25, 90]

# %%
#Implementasi Quick Sort

def quick_sort(arr):
  if len(arr) <= 1:
    return arr

  pivot = arr[len(arr) // 2]
  left = [x for x in arr if x < pivot]
  middle = [x for x in arr if x == pivot]
  right = [x for x in arr if x > pivot]

  return quick_sort(left) + middle + quick_sort(right)

#Contoh penggunaan
data = [64, 25, 12, 22, 11]
sorted_data = quick_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Quick Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 25, 12, 22, 11]
# Data setelah Quick Sort: [11, 12, 22, 25, 64]

# %%
def quick_sort(arr, kriteria):
    if len(arr) <= 1:
        return arr

    if kriteria == "harga":
        pivot = arr[len(arr) // 2][1]
        left = [x for x in arr if x[1] < pivot]
        middle = [x for x in arr if x[1] == pivot]
        right = [x for x in arr if x[1] > pivot]
    else:
        pivot = arr[len(arr) // 2][2]
        left = [x for x in arr if x[2] > pivot]
        middle = [x for x in arr if x[2] == pivot]
        right = [x for x in arr if x[2] < pivot]

    return quick_sort(left, kriteria) + middle + quick_sort(right, kriteria)

produk = [
    ("Sepatu", 350000, 4.2),
    ("Kaos", 100000, 4.8),
    ("Celana", 250000, 4.1),
    ("Jaket", 450000, 4.5),
    ("Topi", 120000, 4.9),
    ("Tas", 180000, 4.3),
    ("Jam Tangan", 300000, 4.7),
    ("Kemeja", 220000, 4.6)
]

print("SEBELUM SORTING:")
for nama, harga, rating in produk:
    print(f"{nama:<12} Rp {harga}  {rating}")

print("-"*35)
print("QUICK SORT BERDASARKAN HARGA TERENDAH:")
sorted_harga = quick_sort(produk.copy(), "harga")
for nama, harga, rating in sorted_harga:
    print(f"{nama:<12} Rp {harga}  {rating}")

print("-"*35)
print("QUICK SORT BERDASARKAN RATING TERTINGGI:")
sorted_rating = quick_sort(produk.copy(), "rating")
for nama, harga, rating in sorted_rating:
    print(f"{nama:<12} Rp {harga}  {rating}")
# Out:
# SEBELUM SORTING:
# Sepatu       Rp 350000  4.2
# Kaos         Rp 100000  4.8
# Celana       Rp 250000  4.1
# Jaket        Rp 450000  4.5
# Topi         Rp 120000  4.9
# Tas          Rp 180000  4.3
# Jam Tangan   Rp 300000  4.7
# Kemeja       Rp 220000  4.6
# -----------------------------------
# QUICK SORT BERDASARKAN HARGA TERENDAH:
# Kaos         Rp 100000  4.8
# Topi         Rp 120000  4.9
# Tas          Rp 180000  4.3
# Kemeja       Rp 220000  4.6
# Celana       Rp 250000  4.1
# Jam Tangan   Rp 300000  4.7
# Sepatu       Rp 350000  4.2
# Jaket        Rp 450000  4.5
# -----------------------------------
# QUICK SORT BERDASARKAN RATING TERTINGGI:
# Topi         Rp 120000  4.9
# Kaos         Rp 100000  4.8
# Jam Tangan   Rp 300000  4.7
# Kemeja       Rp 220000  4.6
# Jaket        Rp 450000  4.5
# Tas          Rp 180000  4.3
# Sepatu       Rp 350000  4.2
# Celana       Rp 250000  4.1
